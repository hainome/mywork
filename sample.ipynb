# %%
#coding: utf-8
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
import chainer
import MeCab
import gym
import cv2

# %%
x = np.linspace(-5, 5, 100)
y = 1 / (1 + np.exp(-x))
plt.plot(x, y, label="sigmoid function")
plt.grid(True)
plt.legend(loc="best")
